# %%
# find all functions defined in a notebook. make it into a text file, then....
import re

with open("Endotaxis-C.txt","r") as file_one:
    patrn = '(?<=def).*(?=:)'
    for line in file_one:
        if re.search(patrn, line):
            print(line)
# Out:
#     "def MakeHanoiGraph(n):\n",
#
#     "    def width(n): # side length of the triangle of level n graph\n",
#
#     "    def doHanoi(x,y,n): # make a level n graph with bottom left at (x,y)\n",
#
#     "def AdjRing(n):\n",
#
#     "def AdjHanoi(n=3):\n",
#
#     "def AdjBinary(n=6): # n must be even for square maze\n",
#
#     "def Floyd(A): # Floyd–Warshall algorithm\n",
#
#     "def SystematicWalkBinary(l=6):\n",
#
#     "def SystematicWalkRing(n=50):\n",
#
#     "def RandomWalkComplete(A,start=0,seed=0):\n",
#
#     "def DirectWalk(A,start,goal):\n",
#
#     "def RandomWalk(A,start=0,seed=0,length=1000):\n",
#
#     "def ShortWalk(A,start=0,seed=0):\n",
#
#     "def TestWalk(A,P):\n",
#
#     "def OccupRandomWalk(A):\n",
#
#     "def ShortWalkHanoi():\n",
#
#     "def P_max(g,no):\n",
#
#     "def T_avg(Q,g):\n",
#
#     "def Steps(A,E,F,no): \n",
#
#     "def Nav_Sim(A,F,M,G,ga,no,warn=True):\n",
#
#     "def Goal(A,D,ga):\n",
#
#     "def do_binary_gain_m(ax):\n",
#
# ...

# %%
import numpy as np

np.mean([13,9,18,11,18,11]),np.mean([2, 7, 7, 7, 6, 8])
# Out:
# (13.333333333333334, 6.166666666666667)
